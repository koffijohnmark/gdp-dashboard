# %% [markdown]
# <a href="https://colab.research.google.com/github/koffijohnmark/gdp-dashboard/blob/main/Another_copy_of_Exercise_1_3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 1.3.1
#
# **Task 1**
#
# Answer the following using Python:
#
# What is your name? Assign the value to the variable `name`
#
# How old are you? Assign the value to the variable `age`
#
# Are you a male or female? Assign the value to the variable `gender`
#
# What state did you come from? Assign the value to the variable `state`
#
# What language can you speak? Assign the value to the variable `language`
#
# True or False, do you smile today? Assign the value to the variable `smile`
#
# ---
#
# The list of the variables to create and assign values to are:
#
# `name`
#
# `age`
#
# `gender`
#
# `state`
#
# `language`
#
# `smile`

# %%
### CG T1
### write your code here:

name = "Aondohemba Johnmark koffi"

age = 26

gender = "Male"

state = "Benue"

language = "English"

smile = True # or false

# %% [markdown]
# **Task 2**
#
# Explain why some variable names in the example are acceptable and why some are not in Python
#
# <img src="https://drive.google.com/uc?id=1NDbTGuy71awYbBNdwV3I14tAF7Fk91j_">

# %% [markdown]
# ### CG T2
# ### Write your answer here for sample variable names
#
# 	•	grade_test – uses only letters and underscore. . covid_19_cases – includes letters, numbers, and underscores only.    term2 – starts with a letter and contains a number, which is allowed.
# 	•	Sale_price_2021 – letters, underscores, and numbers are valid.
#
#
# 	•	miva_learners – uses letters and underscore only.
#
# Unacceptable Variable Names:
#
# 	•	test(grade) – parentheses () are not allowed in variable names.•	covid-19-cases – the hyphen - is invalid because Python interprets it as a minus sign.
# 	•	2 term – cannot start with a number and cannot contain a space.•	2021sales_price – cannot begin with a number. •	miva&learners – the ampersand & is not allowed in variable names.
